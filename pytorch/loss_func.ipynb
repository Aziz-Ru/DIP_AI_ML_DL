# %%
import torch
import torch.nn as nn
import numpy as np
# সরাসরি ফাংশন ব্যবহার
# m = nn.GELU()
# input = torch.randn(2)
# print(input)
# output = m(input)
# print(output)

x = np.random.rand(19,2)
print(x)
xt =torch.Tensor(x)
print(xt)
# Out:
# [[0.68052439 0.09707278]
#  [0.05224806 0.63387175]
#  [0.56626593 0.68448971]
#  [0.56917971 0.92307537]
#  [0.89971043 0.8145196 ]
#  [0.62666702 0.2080751 ]
#  [0.90571086 0.3329875 ]
#  [0.97502903 0.47545516]
#  [0.10515667 0.43020562]
#  [0.08088134 0.88705219]
#  [0.98953175 0.24441226]
#  [0.63741787 0.59037811]
#  [0.5470183  0.24915522]
#  [0.90157425 0.26175649]
#  [0.29997572 0.36641885]
#  [0.82088567 0.13065794]
#  [0.17915658 0.79498004]
#  [0.08199182 0.28668285]
#  [0.13010252 0.15836611]]
# tensor([[0.6805, 0.0971],
#         [0.0522, 0.6339],
#         [0.5663, 0.6845],
#         [0.5692, 0.9231],
#         [0.8997, 0.8145],
#         [0.6267, 0.2081],
#         [0.9057, 0.3330],
#         [0.9750, 0.4755],
#         [0.1052, 0.4302],
#         [0.0809, 0.8871],
#         [0.9895, 0.2444],
#         [0.6374, 0.5904],
#         [0.5470, 0.2492],
#         [0.9016, 0.2618],
#         [0.3000, 0.3664],
#         [0.8209, 0.1307],
#         [0.1792, 0.7950],
# ...
