# %%
import torch
import torch.nn as nn

# সরাসরি ফাংশন ব্যবহার
m = nn.GELU()
input = torch.randn(2)
print(input)
output = m(input)
print(output)
# Out:
# tensor([0.2190, 0.7042])
# tensor([0.1285, 0.5348])
